# %% [markdown]
# <a href="https://colab.research.google.com/github/kadentowle/DSC110/blob/main/Intro%20_to_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random # Random numbers are a library in python?

# I wrote this code and I hope it demonstrates what we did in class, it demonstrates printing, matrices (which are lists), dictionaries, variables, f-strings, equations with integers and variables, functions, and if statements

# ------------------------ MATRIX ------------------------

matrix = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]

victorydictonary ={
    '1':"You got it first try.",
    '2':"Lucky, you got it 2nd try.",
    '3':"Nice, you got it on your 3rd try.",
    '4':"Close, you got it on your last try.",
    '5':"YOU LOST"
}

livesdictionary ={
    '4':"[<3 <3 <3 <3]",
    '3':"[<3 <3 <3 XX]",
    '2':"[<3 <3 XX XX]",
    '1':"[<3 XX XX XX]",
    '0':" :( END :( "
}

# ------------------------ VARIABLES ------------------------

randx = random.randint(0, 2)
randy = random.randint(0, 2)
secret = matrix[randx][randy]

# ------------------------ TEMP ------------------------

tempc = (secret*10)-32/1.8-0.222222222222222 # This is tempature calculation from F to C, (secret*10) is the temp in F and it's converted with /1.8-0.222...

# ------------------------ CODE ---------------------------

choice = None

lives = 4

def printlives():
   print(livesdictionary[f'{lives}'])

trys = 1 # I'm not sure if this has to be a variable.

while choice != secret: # while was a bit confusing to me until I wrote this out.

  if trys == 1:
    print("LIVES"), printlives(), print("TEMP (C): ",tempc)
    choice = int(input("Pick a number 1-9: ")) # inputs can be very fun.
  else:
    if lives > 0:
      choice = int(input(""))
    else:
      print()
  if choice == secret:
    print(victorydictonary[f'{trys}']) # I learned f-strings from your lecture!
  else:
    lives -= 1
    if lives > 0:
      printlives()
      print("you lost a life, try again")
      trys += 1
    else:
      printlives()
# Out:
# LIVES
# [<3 <3 <3 <3]
# TEMP (C):  72.0
# Pick a number 1-9: 8
# [<3 <3 <3 XX]
# you lost a life, try again
# 6
# [<3 <3 XX XX]
# you lost a life, try again
# 7
# [<3 XX XX XX]
# you lost a life, try again
# 9
# Close, you got it on your last try.

# %%
# ------------------------ body mass index code ------------------------
# (BMI = weight (kg) / height (m²))
def calculatebmi(heightlb,weightlb):
  bmi = weightlb/(heightin*heightin)
  if bmi<20:
    print('underweight')
  else:
    print('Normal')

weight = int(input("weight (kg)"))
height = int(input("height (m)"))

calculatebmi(weight,height)
# Out:
# weight (kg)70
# height (m)140
# Normal
